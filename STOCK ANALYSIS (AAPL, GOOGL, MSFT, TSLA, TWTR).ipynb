# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %%
ticker = ['AAPL','MSFT','GOOGL', 'AMZN', 'TSLA', 'TWTR']

# %%
stocks = yf.download(ticker, start='2012-01-01', end='2022-08-15')
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks.tail(5)
# Out:
#              Adj Close                                                  \
#                   AAPL        AMZN       GOOGL        MSFT        TSLA
# Date
# 2022-08-08  164.869995  139.410004  117.300003  280.320007  871.270020
# 2022-08-09  164.919998  137.830002  116.629997  282.299988  850.000000
# 2022-08-10  169.240005  142.690002  119.699997  289.160004  883.070007
# 2022-08-11  168.490005  140.639999  118.839996  287.019989  859.890015
# 2022-08-12  172.100006  143.550003  121.680000  291.910004  900.090027
#
#                             Close                                      ...  \
#                  TWTR        AAPL        AMZN       GOOGL        MSFT  ...
# Date                                                                   ...
# 2022-08-08  42.939999  164.869995  139.410004  117.300003  280.320007  ...
# 2022-08-09  42.830002  164.919998  137.830002  116.629997  282.299988  ...
# 2022-08-10  44.430000  169.240005  142.690002  119.699997  289.160004  ...
# 2022-08-11  43.939999  168.490005  140.639999  118.839996  287.019989  ...
# 2022-08-12  44.259998  172.100006  143.550003  121.680000  291.910004  ...
#
#                   Open                                       Volume            \
#                  GOOGL        MSFT        TSLA       TWTR      AAPL      AMZN
# Date
# 2022-08-08  118.389999  284.049988  885.000000  42.939999  60276900  52229000
# 2022-08-09  117.139999  279.640015  870.880005  42.779999  63135500  40434700
# 2022-08-10  118.779999  288.170013  891.200012  44.520000  70170500  54773800
# 2022-08-11  121.279999  290.850006  889.539978  44.369999  57149200  44867300
# 2022-08-12  120.260002  288.480011  868.250000  44.009998  67946400  47582800
#
#
#                GOOGL      MSFT      TSLA        TWTR
# Date
# 2022-08-08  19138300  18739200  32998000   8130900.0
# 2022-08-09  19086500  23405200  28748200   8309600.0
# 2022-08-10  30930400  24687800  31639600  14507200.0
# 2022-08-11  24293700  20065900  23385000   7254900.0
# 2022-08-12  19074200  22601900  26443300   7852200.0
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2671 entries, 2012-01-03 to 2022-08-12
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, AAPL)   2671 non-null   float64
#  1   (Adj Close, AMZN)   2671 non-null   float64
#  2   (Adj Close, GOOGL)  2671 non-null   float64
#  3   (Adj Close, MSFT)   2671 non-null   float64
#  4   (Adj Close, TSLA)   2671 non-null   float64
#  5   (Adj Close, TWTR)   2206 non-null   float64
#  6   (Close, AAPL)       2671 non-null   float64
#  7   (Close, AMZN)       2671 non-null   float64
#  8   (Close, GOOGL)      2671 non-null   float64
#  9   (Close, MSFT)       2671 non-null   float64
#  10  (Close, TSLA)       2671 non-null   float64
#  11  (Close, TWTR)       2206 non-null   float64
#  12  (High, AAPL)        2671 non-null   float64
#  13  (High, AMZN)        2671 non-null   float64
#  14  (High, GOOGL)       2671 non-null   float64
#  15  (High, MSFT)        2671 non-null   float64
#  16  (High, TSLA)        2671 non-null   float64
#  17  (High, TWTR)        2206 non-null   float64
#  18  (Low, AAPL)         2671 non-null   float64
#  19  (Low, AMZN)         2671 non-null   float64
#  20  (Low, GOOGL)        2671 non-null   float64
#  21  (Low, MSFT)         2671 non-null   float64
#  22  (Low, TSLA)         2671 non-null   float64
#  23  (Low, TWTR)         2206 non-null   float64
#  24  (Open, AAPL)        2671 non-null   float64
#  25  (Open, AMZN)        2671 non-null   float64
#  26  (Open, GOOGL)       2671 non-null   float64
#  27  (Open, MSFT)        2671 non-null   float64
#  28  (Open, TSLA)        2671 non-null   float64
#  29  (Open, TWTR)        2206 non-null   float64
#  30  (Volume, AAPL)      2671 non-null   int64
#  31  (Volume, AMZN)      2671 non-null   int64
#  32  (Volume, GOOGL)     2671 non-null   int64
#  33  (Volume, MSFT)      2671 non-null   int64
#  34  (Volume, TSLA)      2671 non-null   int64
#  35  (Volume, TWTR)      2206 non-null   float64
# dtypes: float64(31), int64(5)
# memory usage: 772.1 KB

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',  'AAPL'),
#             ('Adj Close',  'AMZN'),
#             ('Adj Close', 'GOOGL'),
#             ('Adj Close',  'MSFT'),
#             ('Adj Close',  'TSLA'),
#             ('Adj Close',  'TWTR'),
#             (    'Close',  'AAPL'),
#             (    'Close',  'AMZN'),
#             (    'Close', 'GOOGL'),
#             (    'Close',  'MSFT'),
#             (    'Close',  'TSLA'),
#             (    'Close',  'TWTR'),
#             (     'High',  'AAPL'),
#             (     'High',  'AMZN'),
#             (     'High', 'GOOGL'),
#             (     'High',  'MSFT'),
#             (     'High',  'TSLA'),
#             (     'High',  'TWTR'),
#             (      'Low',  'AAPL'),
#             (      'Low',  'AMZN'),
#             (      'Low', 'GOOGL'),
#             (      'Low',  'MSFT'),
#             (      'Low',  'TSLA'),
#             (      'Low',  'TWTR'),
#             (     'Open',  'AAPL'),
#             (     'Open',  'AMZN'),
#             (     'Open', 'GOOGL'),
#             (     'Open',  'MSFT'),
#             (     'Open',  'TSLA'),
#             (     'Open',  'TWTR'),
#             (   'Volume',  'AAPL'),
#             (   'Volume',  'AMZN'),
#             (   'Volume', 'GOOGL'),
#             (   'Volume',  'MSFT'),
#             (   'Volume',  'TSLA'),
#             (   'Volume',  'TWTR')],
#            )

# %%
stocks.index
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2022-08-01', '2022-08-02', '2022-08-03', '2022-08-04',
#                '2022-08-05', '2022-08-08', '2022-08-09', '2022-08-10',
#                '2022-08-11', '2022-08-12'],
#               dtype='datetime64[ns]', name='Date', length=2671, freq=None)

# %%
stocks.to_csv('stocks.csv')

# %%
stocks = pd.read_csv('stocks.csv', header = [0,1], index_col = [0], parse_dates=[0])

# %%
stocks.head(9)
# Out:
#             Adj Close                                                Close  \
#                  AAPL    AMZN      GOOGL       MSFT   TSLA TWTR       AAPL
# Date
# 2012-01-03  12.540047  8.9515  16.651901  21.572889  5.616  NaN  14.686786
# 2012-01-04  12.607437  8.8755  16.723724  22.080582  5.542  NaN  14.765714
# 2012-01-05  12.747405  8.8805  16.491741  22.306227  5.424  NaN  14.929643
# 2012-01-06  12.880665  9.1305  16.266768  22.652744  5.382  NaN  15.085714
# 2012-01-09  12.860230  8.9280  15.577077  22.354578  5.450  NaN  15.061786
# 2012-01-10  12.906278  8.9670  15.594094  22.435162  5.524  NaN  15.115714
# 2012-01-11  12.885234  8.9450  15.664665  22.338457  5.646  NaN  15.091071
# 2012-01-12  12.849866  8.7965  15.756757  22.564098  5.650  NaN  15.049643
# 2012-01-13  12.801683  8.9210  15.640390  22.765560  4.558  NaN  14.993214
#
#                                           ...       Open                    \
#               AMZN      GOOGL       MSFT  ...      GOOGL       MSFT   TSLA
# Date                                      ...
# 2012-01-03  8.9515  16.651901  26.770000  ...  16.339840  26.549999  5.788
# 2012-01-04  8.8755  16.723724  27.400000  ...  16.642391  26.820000  5.642
# 2012-01-05  8.8805  16.491741  27.680000  ...  16.569820  27.379999  5.552
# 2012-01-06  9.1305  16.266768  28.110001  ...  16.495245  27.530001  5.440
# 2012-01-09  8.9280  15.577077  27.740000  ...  16.178679  28.049999  5.400
# 2012-01-10  8.9670  15.594094  27.840000  ...  15.759510  27.930000  5.488
# 2012-01-11  8.9450  15.664665  27.719999  ...  15.603103  27.430000  5.524
# 2012-01-12  8.7965  15.756757  28.000000  ...  15.796296  27.870001  5.696
# 2012-01-13  8.9210  15.640390  28.250000  ...  15.672172  27.930000  5.680
#
#                     Volume
#            TWTR       AAPL       AMZN      GOOGL      MSFT      TSLA TWTR
# Date
# 2012-01-03  NaN  302220800  102216000  146912940  64731500   4640500  NaN
# 2012-01-04  NaN  260022000   84104000  114445440  80516100   3150500  NaN
# 2012-01-05  NaN  271269600   76182000  131184684  56081400   5027500  NaN
# 2012-01-06  NaN  318292800  140168000  107608284  99455500   4931500  NaN
# 2012-01-09  NaN  394024400  101138000  232671096  59706800   4485000  NaN
# 2012-01-10  NaN  258196400   79716000  175648176  60014400   3359000  NaN
# 2012-01-11  NaN  215084800   62054000   95904000  65582400   3361500  NaN
# 2012-01-12  NaN  212587200  107716000   74932992  49370800   3646500  NaN
# 2012-01-13  NaN  226021600   95070000   92199708  60196100  27502000  NaN
#
# [9 rows x 36 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',  'AAPL'),
#             ('Adj Close',  'AMZN'),
#             ('Adj Close', 'GOOGL'),
#             ('Adj Close',  'MSFT'),
#             ('Adj Close',  'TSLA'),
#             ('Adj Close',  'TWTR'),
#             (    'Close',  'AAPL'),
#             (    'Close',  'AMZN'),
#             (    'Close', 'GOOGL'),
#             (    'Close',  'MSFT'),
#             (    'Close',  'TSLA'),
#             (    'Close',  'TWTR'),
#             (     'High',  'AAPL'),
#             (     'High',  'AMZN'),
#             (     'High', 'GOOGL'),
#             (     'High',  'MSFT'),
#             (     'High',  'TSLA'),
#             (     'High',  'TWTR'),
#             (      'Low',  'AAPL'),
#             (      'Low',  'AMZN'),
#             (      'Low', 'GOOGL'),
#             (      'Low',  'MSFT'),
#             (      'Low',  'TSLA'),
#             (      'Low',  'TWTR'),
#             (     'Open',  'AAPL'),
#             (     'Open',  'AMZN'),
#             (     'Open', 'GOOGL'),
#             (     'Open',  'MSFT'),
#             (     'Open',  'TSLA'),
#             (     'Open',  'TWTR'),
#             (   'Volume',  'AAPL'),
#             (   'Volume',  'AMZN'),
#             (   'Volume', 'GOOGL'),
#             (   'Volume',  'MSFT'),
#             (   'Volume',  'TSLA'),
#             (   'Volume',  'TWTR')],
#            )

# %%
stocks.columns.to_flat_index()
# Out:
# Index([ ('Adj Close', 'AAPL'),  ('Adj Close', 'AMZN'), ('Adj Close', 'GOOGL'),
#         ('Adj Close', 'MSFT'),  ('Adj Close', 'TSLA'),  ('Adj Close', 'TWTR'),
#             ('Close', 'AAPL'),      ('Close', 'AMZN'),     ('Close', 'GOOGL'),
#             ('Close', 'MSFT'),      ('Close', 'TSLA'),      ('Close', 'TWTR'),
#              ('High', 'AAPL'),       ('High', 'AMZN'),      ('High', 'GOOGL'),
#              ('High', 'MSFT'),       ('High', 'TSLA'),       ('High', 'TWTR'),
#               ('Low', 'AAPL'),        ('Low', 'AMZN'),       ('Low', 'GOOGL'),
#               ('Low', 'MSFT'),        ('Low', 'TSLA'),        ('Low', 'TWTR'),
#              ('Open', 'AAPL'),       ('Open', 'AMZN'),      ('Open', 'GOOGL'),
#              ('Open', 'MSFT'),       ('Open', 'TSLA'),       ('Open', 'TWTR'),
#            ('Volume', 'AAPL'),     ('Volume', 'AMZN'),    ('Volume', 'GOOGL'),
#            ('Volume', 'MSFT'),     ('Volume', 'TSLA'),     ('Volume', 'TWTR')],
#       dtype='object')

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks.head()
# Out:
#             Adj Close                                                Close  \
#                  AAPL    AMZN      GOOGL       MSFT   TSLA TWTR       AAPL
# Date
# 2012-01-03  12.540047  8.9515  16.651901  21.572889  5.616  NaN  14.686786
# 2012-01-04  12.607437  8.8755  16.723724  22.080582  5.542  NaN  14.765714
# 2012-01-05  12.747405  8.8805  16.491741  22.306227  5.424  NaN  14.929643
# 2012-01-06  12.880665  9.1305  16.266768  22.652744  5.382  NaN  15.085714
# 2012-01-09  12.860230  8.9280  15.577077  22.354578  5.450  NaN  15.061786
#
#                                           ...       Open                    \
#               AMZN      GOOGL       MSFT  ...      GOOGL       MSFT   TSLA
# Date                                      ...
# 2012-01-03  8.9515  16.651901  26.770000  ...  16.339840  26.549999  5.788
# 2012-01-04  8.8755  16.723724  27.400000  ...  16.642391  26.820000  5.642
# 2012-01-05  8.8805  16.491741  27.680000  ...  16.569820  27.379999  5.552
# 2012-01-06  9.1305  16.266768  28.110001  ...  16.495245  27.530001  5.440
# 2012-01-09  8.9280  15.577077  27.740000  ...  16.178679  28.049999  5.400
#
#                     Volume
#            TWTR       AAPL       AMZN      GOOGL      MSFT     TSLA TWTR
# Date
# 2012-01-03  NaN  302220800  102216000  146912940  64731500  4640500  NaN
# 2012-01-04  NaN  260022000   84104000  114445440  80516100  3150500  NaN
# 2012-01-05  NaN  271269600   76182000  131184684  56081400  5027500  NaN
# 2012-01-06  NaN  318292800  140168000  107608284  99455500  4931500  NaN
# 2012-01-09  NaN  394024400  101138000  232671096  59706800  4485000  NaN
#
# [5 rows x 36 columns]

# %%
stocks.swaplevel(axis=1).sort_index(axis=1)
# Out:
#                   AAPL                                                  \
#              Adj Close       Close        High         Low        Open
# Date
# 2012-01-03   12.540047   14.686786   14.732143   14.607143   14.621429
# 2012-01-04   12.607437   14.765714   14.810000   14.617143   14.642857
# 2012-01-05   12.747405   14.929643   14.948214   14.738214   14.819643
# 2012-01-06   12.880665   15.085714   15.098214   14.972143   14.991786
# 2012-01-09   12.860230   15.061786   15.276786   15.048214   15.196429
# ...                ...         ...         ...         ...         ...
# 2022-08-08  164.869995  164.869995  167.809998  164.199997  166.369995
# 2022-08-09  164.919998  164.919998  165.820007  163.250000  164.020004
# 2022-08-10  169.240005  169.240005  169.339996  166.899994  167.679993
# 2022-08-11  168.490005  168.490005  170.990005  168.190002  170.059998
# 2022-08-12  172.100006  172.100006  172.169998  169.399994  169.820007
#
#                              AMZN                                      ...  \
#                Volume   Adj Close       Close        High         Low  ...
# Date                                                                   ...
# 2012-01-03  302220800    8.951500    8.951500    8.974000    8.777500  ...
# 2012-01-04  260022000    8.875500    8.875500    9.025000    8.803500  ...
# 2012-01-05  271269600    8.880500    8.880500    8.912500    8.702500  ...
# 2012-01-06  318292800    9.130500    9.130500    9.232500    8.875000  ...
# 2012-01-09  394024400    8.928000    8.928000    9.218500    8.850000  ...
# ...               ...         ...         ...         ...         ...  ...
# 2022-08-08   60276900  139.410004  139.410004  144.229996  138.289993  ...
# 2022-08-09   63135500  137.830002  137.830002  138.949997  136.210007  ...
# 2022-08-10   70170500  142.690002  142.690002  144.600006  141.009995  ...
# 2022-08-11   57149200  140.639999  140.639999  144.490005  139.759995  ...
# 2022-08-12   67946400  143.550003  143.550003  143.570007  140.119995  ...
#
#                   TSLA                                         TWTR  \
#                   High         Low        Open    Volume  Adj Close
# Date
# 2012-01-03    5.900000    5.530000    5.788000   4640500        NaN
# 2012-01-04    5.734000    5.500000    5.642000   3150500        NaN
# 2012-01-05    5.586000    5.370000    5.552000   5027500        NaN
# 2012-01-06    5.558000    5.282000    5.440000   4931500        NaN
# 2012-01-09    5.498000    5.224000    5.400000   4485000        NaN
# ...                ...         ...         ...       ...        ...
# 2022-08-08  915.599976  867.260010  885.000000  32998000  42.939999
# 2022-08-09  877.190002  838.059998  870.880005  28748200  42.830002
# 2022-08-10  892.530029  850.109985  891.200012  31639600  44.430000
# 2022-08-11  894.710022  857.500000  889.539978  23385000  43.939999
# 2022-08-12  900.479980  855.099976  868.250000  26443300  44.259998
#
#
#                 Close       High        Low       Open      Volume
# Date
# 2012-01-03        NaN        NaN        NaN        NaN         NaN
# 2012-01-04        NaN        NaN        NaN        NaN         NaN
# 2012-01-05        NaN        NaN        NaN        NaN         NaN
# 2012-01-06        NaN        NaN        NaN        NaN         NaN
# 2012-01-09        NaN        NaN        NaN        NaN         NaN
# ...               ...        ...        ...        ...         ...
# 2022-08-08  42.939999  43.549999  42.869999  42.939999   8130900.0
# 2022-08-09  42.830002  43.119999  42.599998  42.779999   8309600.0
# 2022-08-10  44.430000  44.650002  43.830002  44.520000  14507200.0
# 2022-08-11  43.939999  44.630001  43.639999  44.369999   7254900.0
# 2022-08-12  44.259998  44.599998  43.930000  44.009998   7852200.0
#
# [2671 rows x 36 columns]

# %% [markdown]
# # Initial Inspection and Visualization

# %%
import pandas as pd

# %%
stocks = pd.read_csv('stocks.csv', header=[0,1], index_col = [0], parse_dates=[0])

# %%
stocks.head(2)
# Out:
#             Adj Close                                                Close  \
#                  AAPL    AMZN      GOOGL       MSFT   TSLA TWTR       AAPL
# Date
# 2012-01-03  12.540047  8.9515  16.651901  21.572889  5.616  NaN  14.686786
# 2012-01-04  12.607437  8.8755  16.723724  22.080582  5.542  NaN  14.765714
#
#                                       ...       Open                         \
#               AMZN      GOOGL   MSFT  ...      GOOGL       MSFT   TSLA TWTR
# Date                                  ...
# 2012-01-03  8.9515  16.651901  26.77  ...  16.339840  26.549999  5.788  NaN
# 2012-01-04  8.8755  16.723724  27.40  ...  16.642391  26.820000  5.642  NaN
#
#                Volume
#                  AAPL       AMZN      GOOGL      MSFT     TSLA TWTR
# Date
# 2012-01-03  302220800  102216000  146912940  64731500  4640500  NaN
# 2012-01-04  260022000   84104000  114445440  80516100  3150500  NaN
#
# [2 rows x 36 columns]

# %%
stocks.tail(2)
# Out:
#              Adj Close                                                  \
#                   AAPL        AMZN       GOOGL        MSFT        TSLA
# Date
# 2022-08-11  168.490005  140.639999  118.839996  287.019989  859.890015
# 2022-08-12  172.100006  143.550003  121.680000  291.910004  900.090027
#
#                             Close                                      ...  \
#                  TWTR        AAPL        AMZN       GOOGL        MSFT  ...
# Date                                                                   ...
# 2022-08-11  43.939999  168.490005  140.639999  118.839996  287.019989  ...
# 2022-08-12  44.259998  172.100006  143.550003  121.680000  291.910004  ...
#
#                   Open                                       Volume            \
#                  GOOGL        MSFT        TSLA       TWTR      AAPL      AMZN
# Date
# 2022-08-11  121.279999  290.850006  889.539978  44.369999  57149200  44867300
# 2022-08-12  120.260002  288.480011  868.250000  44.009998  67946400  47582800
#
#
#                GOOGL      MSFT      TSLA       TWTR
# Date
# 2022-08-11  24293700  20065900  23385000  7254900.0
# 2022-08-12  19074200  22601900  26443300  7852200.0
#
# [2 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2671 entries, 2012-01-03 to 2022-08-12
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, AAPL)   2671 non-null   float64
#  1   (Adj Close, AMZN)   2671 non-null   float64
#  2   (Adj Close, GOOGL)  2671 non-null   float64
#  3   (Adj Close, MSFT)   2671 non-null   float64
#  4   (Adj Close, TSLA)   2671 non-null   float64
#  5   (Adj Close, TWTR)   2206 non-null   float64
#  6   (Close, AAPL)       2671 non-null   float64
#  7   (Close, AMZN)       2671 non-null   float64
#  8   (Close, GOOGL)      2671 non-null   float64
#  9   (Close, MSFT)       2671 non-null   float64
#  10  (Close, TSLA)       2671 non-null   float64
#  11  (Close, TWTR)       2206 non-null   float64
#  12  (High, AAPL)        2671 non-null   float64
#  13  (High, AMZN)        2671 non-null   float64
#  14  (High, GOOGL)       2671 non-null   float64
#  15  (High, MSFT)        2671 non-null   float64
#  16  (High, TSLA)        2671 non-null   float64
#  17  (High, TWTR)        2206 non-null   float64
#  18  (Low, AAPL)         2671 non-null   float64
#  19  (Low, AMZN)         2671 non-null   float64
#  20  (Low, GOOGL)        2671 non-null   float64
#  21  (Low, MSFT)         2671 non-null   float64
#  22  (Low, TSLA)         2671 non-null   float64
#  23  (Low, TWTR)         2206 non-null   float64
#  24  (Open, AAPL)        2671 non-null   float64
#  25  (Open, AMZN)        2671 non-null   float64
#  26  (Open, GOOGL)       2671 non-null   float64
#  27  (Open, MSFT)        2671 non-null   float64
#  28  (Open, TSLA)        2671 non-null   float64
#  29  (Open, TWTR)        2206 non-null   float64
#  30  (Volume, AAPL)      2671 non-null   int64
#  31  (Volume, AMZN)      2671 non-null   int64
#  32  (Volume, GOOGL)     2671 non-null   int64
#  33  (Volume, MSFT)      2671 non-null   int64
#  34  (Volume, TSLA)      2671 non-null   int64
#  35  (Volume, TWTR)      2206 non-null   float64
# dtypes: float64(31), int64(5)
# memory usage: 772.1 KB

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AAPL         AMZN        GOOGL         MSFT         TSLA
# count  2671.000000  2671.000000  2671.000000  2671.000000  2671.000000
# mean     53.513269    66.625480    54.000513   104.431538   182.823454
# std      46.178477    54.205400    34.874822    88.769179   287.339088
# min      12.084598     8.796500    13.990240    21.572889     4.558000
# 25%      21.670159    17.469500    27.710750    37.184761    40.034000
# 50%      33.845741    45.464001    44.442001    63.171150    51.094002
# 75%      64.686241    96.148998    63.850500   147.701591    76.845001
# max     181.259918   186.570496   149.838501   341.606354  1229.910034
#
#                           Close                                         ...  \
#               TWTR         AAPL         AMZN        GOOGL         MSFT  ...
# count  2206.000000  2671.000000  2671.000000  2671.000000  2671.000000  ...
# mean     35.790462    55.376978    66.625480    54.000513   108.667945  ...
# std      14.170961    45.593831    54.205400    34.874822    87.496112  ...
# min      14.010000    13.947500     8.796500    13.990240    26.370001  ...
# 25%      25.139999    23.982678    17.469500    27.710750    42.325001  ...
# 50%      35.005001    35.919998    45.464001    44.442001    67.529999  ...
# 75%      43.929999    65.918751    96.148998    63.850500   151.180000  ...
# max      77.629997   182.009995   186.570496   149.838501   343.109985  ...
#
#               Open                                               Volume  \
#              GOOGL         MSFT         TSLA         TWTR          AAPL
# count  2671.000000  2671.000000  2671.000000  2206.000000  2.671000e+03
# mean     53.993866   108.632538   182.868924    35.814325  2.078663e+08
# std      34.879143    87.482593   287.607998    14.205119  1.732815e+08
# min      14.022523    26.379999     5.324000    13.950000  4.100000e+07
# 25%      27.755750    42.250000    40.006001    25.087500  9.804595e+07
# 50%      44.112999    67.480003    51.138000    35.065001  1.433456e+08
# 75%      63.732750   150.995003    76.354000    44.047500  2.556576e+08
# max     151.250000   344.619995  1234.410034    78.360001  1.506120e+09
#
#
#                AMZN         GOOGL          MSFT          TSLA          TWTR
# count  2.671000e+03  2.671000e+03  2.671000e+03  2.671000e+03  2.206000e+03
# mean   8.095476e+07  4.903515e+07  3.387126e+07  3.472087e+07  2.181246e+07
# std    4.331862e+07  3.594369e+07  1.763334e+07  2.758803e+07  1.901386e+07
# min    1.762600e+07  9.312000e+06  7.425600e+06  1.824500e+06  3.661100e+06
# 25%    5.388400e+07  2.782800e+07  2.291340e+07  1.838225e+07  1.251038e+07
# 50%    6.950200e+07  3.647948e+07  2.971960e+07  2.800960e+07  1.705055e+07
# 75%    9.367200e+07  5.926735e+07  3.950000e+07  4.190925e+07  2.429832e+07
# max    4.771220e+08  4.971983e+08  2.484285e+08  3.046940e+08  2.684654e+08
#
# [8 rows x 36 columns]

# %%
stocks.head(3)
# Out:
#             Adj Close                                                Close  \
#                  AAPL    AMZN      GOOGL       MSFT   TSLA TWTR       AAPL
# Date
# 2012-01-03  12.540047  8.9515  16.651901  21.572889  5.616  NaN  14.686786
# 2012-01-04  12.607437  8.8755  16.723724  22.080582  5.542  NaN  14.765714
# 2012-01-05  12.747405  8.8805  16.491741  22.306227  5.424  NaN  14.929643
#
#                                       ...       Open                         \
#               AMZN      GOOGL   MSFT  ...      GOOGL       MSFT   TSLA TWTR
# Date                                  ...
# 2012-01-03  8.9515  16.651901  26.77  ...  16.339840  26.549999  5.788  NaN
# 2012-01-04  8.8755  16.723724  27.40  ...  16.642391  26.820000  5.642  NaN
# 2012-01-05  8.8805  16.491741  27.68  ...  16.569820  27.379999  5.552  NaN
#
#                Volume
#                  AAPL       AMZN      GOOGL      MSFT     TSLA TWTR
# Date
# 2012-01-03  302220800  102216000  146912940  64731500  4640500  NaN
# 2012-01-04  260022000   84104000  114445440  80516100  3150500  NaN
# 2012-01-05  271269600   76182000  131184684  56081400  5027500  NaN
#
# [3 rows x 36 columns]

# %%
close = stocks.loc[:,'Close'].copy()

# %%
close.head()
# Out:
#                  AAPL    AMZN      GOOGL       MSFT   TSLA  TWTR
# Date
# 2012-01-03  14.686786  8.9515  16.651901  26.770000  5.616   NaN
# 2012-01-04  14.765714  8.8755  16.723724  27.400000  5.542   NaN
# 2012-01-05  14.929643  8.8805  16.491741  27.680000  5.424   NaN
# 2012-01-06  15.085714  9.1305  16.266768  28.110001  5.382   NaN
# 2012-01-09  15.061786  8.9280  15.577077  27.740000  5.450   NaN

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
close.plot(figsize=(13,11), fontsize=13)
plt.legend(fontsize=13);

# %% [markdown]
# # Normalizing Time Series to a Base Value (100)

# %%
close.head()
# Out:
#                  AAPL    AMZN      GOOGL       MSFT   TSLA  TWTR
# Date
# 2012-01-03  14.686786  8.9515  16.651901  26.770000  5.616   NaN
# 2012-01-04  14.765714  8.8755  16.723724  27.400000  5.542   NaN
# 2012-01-05  14.929643  8.8805  16.491741  27.680000  5.424   NaN
# 2012-01-06  15.085714  9.1305  16.266768  28.110001  5.382   NaN
# 2012-01-09  15.061786  8.9280  15.577077  27.740000  5.450   NaN

# %%
close.iloc[0,0]
# Out:
# 14.686785697937012

# %%
close.columns
# Out:
# Index(['AAPL', 'AMZN', 'GOOGL', 'MSFT', 'TSLA', 'TWTR'], dtype='object')

# %%
close['AAPL'].div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2012-01-03     100.000000
# 2012-01-04     100.537408
# 2012-01-05     101.653575
# 2012-01-06     102.716242
# 2012-01-09     102.553316
#                  ...
# 2022-08-08    1122.573710
# 2022-08-09    1122.914173
# 2022-08-10    1152.328419
# 2022-08-11    1147.221788
# 2022-08-12    1171.801711
# Name: AAPL, Length: 2671, dtype: float64

# %%
norm = close.div(close.iloc[0,0]).mul(100)
norm
# Out:
#                    AAPL        AMZN       GOOGL         MSFT         TSLA  \
# Date
# 2012-01-03   100.000000   60.949347  113.380161   182.272697    38.238457
# 2012-01-04   100.537408   60.431873  113.869193   186.562262    37.734600
# 2012-01-05   101.653575   60.465918  112.289656   188.468742    36.931156
# 2012-01-06   102.716242   62.168129  110.757846   191.396546    36.645186
# 2012-01-09   102.553316   60.789342  106.061852   188.877269    37.108186
# ...                 ...         ...         ...          ...          ...
# 2022-08-08  1122.573710  949.220657  798.677161  1908.654576  5932.339706
# 2022-08-09  1122.914173  938.462674  794.115198  1922.135950  5787.515509
# 2022-08-10  1152.328419  971.553649  815.018340  1968.844713  6012.683956
# 2022-08-11  1147.221788  957.595503  809.162732  1954.273691  5854.855054
# 2022-08-12  1171.801711  977.409258  828.499869  1987.569027  6128.570576
#
#                   TWTR
# Date
# 2012-01-03         NaN
# 2012-01-04         NaN
# 2012-01-05         NaN
# 2012-01-06         NaN
# 2012-01-09         NaN
# ...                ...
# 2022-08-08  292.371656
# 2022-08-09  291.622706
# 2022-08-10  302.516842
# 2022-08-11  299.180498
# 2022-08-12  301.359326
#
# [2671 rows x 6 columns]

# %%
norm.plot(figsize = (15,8), fontsize = 13)
plt.legend(fontsize=13);

# %%
aapl = close.AAPL.copy().to_frame()
aapl
# Out:
#                   AAPL
# Date
# 2012-01-03   14.686786
# 2012-01-04   14.765714
# 2012-01-05   14.929643
# 2012-01-06   15.085714
# 2012-01-09   15.061786
# ...                ...
# 2022-08-08  164.869995
# 2022-08-09  164.919998
# 2022-08-10  169.240005
# 2022-08-11  168.490005
# 2022-08-12  172.100006
#
# [2671 rows x 1 columns]

# %%
aapl.head()
# Out:
#                  AAPL
# Date
# 2012-01-03  14.686786
# 2012-01-04  14.765714
# 2012-01-05  14.929643
# 2012-01-06  15.085714
# 2012-01-09  15.061786

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2012-01-03         NaN
# 2012-01-04   14.686786
# 2012-01-05   14.765714
# 2012-01-06   14.929643
# 2012-01-09   15.085714
# ...                ...
# 2022-08-08  165.350006
# 2022-08-09  164.869995
# 2022-08-10  164.919998
# 2022-08-11  169.240005
# 2022-08-12  168.490005
#
# [2671 rows x 1 columns]

# %%
aapl['lag1'] = aapl.shift(periods=1)

# %%
aapl.head()
# Out:
#                  AAPL       lag1
# Date
# 2012-01-03  14.686786        NaN
# 2012-01-04  14.765714  14.686786
# 2012-01-05  14.929643  14.765714
# 2012-01-06  15.085714  14.929643
# 2012-01-09  15.061786  15.085714

# %%
aapl.AAPL.sub(aapl.lag1)
# Out:
# Date
# 2012-01-03         NaN
# 2012-01-04    0.078928
# 2012-01-05    0.163929
# 2012-01-06    0.156072
# 2012-01-09   -0.023929
#                 ...
# 2022-08-08   -0.480011
# 2022-08-09    0.050003
# 2022-08-10    4.320007
# 2022-08-11   -0.750000
# 2022-08-12    3.610001
# Length: 2671, dtype: float64

# %%
aapl['Diff'] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl.head()
# Out:
#                  AAPL       lag1      Diff
# Date
# 2012-01-03  14.686786        NaN       NaN
# 2012-01-04  14.765714  14.686786  0.078928
# 2012-01-05  14.929643  14.765714  0.163929
# 2012-01-06  15.085714  14.929643  0.156072
# 2012-01-09  15.061786  15.085714 -0.023929

# %%
aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
# Out:
# Date
# 2012-01-03         NaN
# 2012-01-04    0.537408
# 2012-01-05    1.110200
# 2012-01-06    1.045381
# 2012-01-09   -0.158618
#                 ...
# 2022-08-08   -0.290300
# 2022-08-09    0.030329
# 2022-08-10    2.619456
# 2022-08-11   -0.443158
# 2022-08-12    2.142561
# Length: 2671, dtype: float64

# %%
aapl['pct_change'] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl.head()
# Out:
#                  AAPL       lag1      Diff  pct_change
# Date
# 2012-01-03  14.686786        NaN       NaN         NaN
# 2012-01-04  14.765714  14.686786  0.078928    0.537408
# 2012-01-05  14.929643  14.765714  0.163929    1.110200
# 2012-01-06  15.085714  14.929643  0.156072    1.045381
# 2012-01-09  15.061786  15.085714 -0.023929   -0.158618

# %% [markdown]
# # The methods diff() and pct_change()

# %%
aapl.AAPL.diff(periods = 2)
# Out:
# Date
# 2012-01-03         NaN
# 2012-01-04         NaN
# 2012-01-05    0.242857
# 2012-01-06    0.320001
# 2012-01-09    0.132143
#                 ...
# 2022-08-08   -0.940002
# 2022-08-09   -0.430008
# 2022-08-10    4.370010
# 2022-08-11    3.570007
# 2022-08-12    2.860001
# Name: AAPL, Length: 2671, dtype: float64

# %%
aapl['Diff2'] = aapl.AAPL.diff(periods = 1)

# %%
aapl.head(10)
# Out:
#                  AAPL       lag1      Diff  pct_change     Diff2
# Date
# 2012-01-03  14.686786        NaN       NaN         NaN       NaN
# 2012-01-04  14.765714  14.686786  0.078928    0.537408  0.078928
# 2012-01-05  14.929643  14.765714  0.163929    1.110200  0.163929
# 2012-01-06  15.085714  14.929643  0.156072    1.045381  0.156072
# 2012-01-09  15.061786  15.085714 -0.023929   -0.158618 -0.023929
# 2012-01-10  15.115714  15.061786  0.053928    0.358048  0.053928
# 2012-01-11  15.091071  15.115714 -0.024643   -0.163029 -0.024643
# 2012-01-12  15.049643  15.091071 -0.041429   -0.274524 -0.041429
# 2012-01-13  14.993214  15.049643 -0.056429   -0.374952 -0.056429
# 2012-01-17  15.167857  14.993214  0.174644    1.164817  0.174644

# %%
aapl.Diff.equals(aapl.Diff2)
# Out:
# True

# %%
aapl['pct_change2'] = aapl.AAPL.pct_change(periods=1).mul(100)

# %%
aapl.head(10)
# Out:
#                  AAPL       lag1      Diff  pct_change     Diff2  pct_change2
# Date
# 2012-01-03  14.686786        NaN       NaN         NaN       NaN          NaN
# 2012-01-04  14.765714  14.686786  0.078928    0.537408  0.078928     0.537408
# 2012-01-05  14.929643  14.765714  0.163929    1.110200  0.163929     1.110200
# 2012-01-06  15.085714  14.929643  0.156072    1.045381  0.156072     1.045381
# 2012-01-09  15.061786  15.085714 -0.023929   -0.158618 -0.023929    -0.158618
# 2012-01-10  15.115714  15.061786  0.053928    0.358048  0.053928     0.358048
# 2012-01-11  15.091071  15.115714 -0.024643   -0.163029 -0.024643    -0.163029
# 2012-01-12  15.049643  15.091071 -0.041429   -0.274524 -0.041429    -0.274524
# 2012-01-13  14.993214  15.049643 -0.056429   -0.374952 -0.056429    -0.374952
# 2012-01-17  15.167857  14.993214  0.174644    1.164817  0.174644     1.164817

# %% [markdown]
# # Measuring Stock Performance with MEAN Return and STD of Returns

# %%
import numpy as np

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                  AAPL
# Date
# 2012-01-03  14.686786
# 2012-01-04  14.765714
# 2012-01-05  14.929643
# 2012-01-06  15.085714
# 2012-01-09  15.061786

# %%
aapl.pct_change().dropna()
# Out:
#                 AAPL
# Date
# 2012-01-04  0.005374
# 2012-01-05  0.011102
# 2012-01-06  0.010454
# 2012-01-09 -0.001586
# 2012-01-10  0.003580
# ...              ...
# 2022-08-08 -0.002903
# 2022-08-09  0.000303
# 2022-08-10  0.026195
# 2022-08-11 -0.004432
# 2022-08-12  0.021426
#
# [2670 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret.head()
# Out:
#                 AAPL
# Date
# 2012-01-04  0.005374
# 2012-01-05  0.011102
# 2012-01-06  0.010454
# 2012-01-09 -0.001586
# 2012-01-10  0.003580

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2670 entries, 2012-01-04 to 2022-08-12
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2670 non-null   float64
# dtypes: float64(1)
# memory usage: 41.7 KB

# %%
ret.plot(kind='hist', figsize=(12,8), bins=100);

# %%
daily_mean_Return = ret.mean()
daily_mean_Return
# Out:
# AAPL    0.001086
# dtype: float64

# %%
var_daily_Returns = ret.var()
var_daily_Returns
# Out:
# AAPL    0.000328
# dtype: float64

# %%
std_daily_Returns = np.sqrt(var_daily_Returns)
std_daily_Returns
# Out:
# AAPL    0.018114
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.018114
# dtype: float64

# %%
ann_mean_Returns = ret.mean()*252
ann_mean_Returns
# Out:
# AAPL    0.273793
# dtype: float64

# %%
ann_var_Returns = ret.var()*252
ann_var_Returns
# Out:
# AAPL    0.082687
# dtype: float64

# %%
ann_std_Returns = np.sqrt(ann_var_Returns)
ann_std_Returns
# Out:
# AAPL    0.287553
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.287553
# dtype: float64

# %% [markdown]
# # Financial Time Series - Return and Risk

# %%
import numpy as np

# %%
norm.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize = 13);

# %%
close.head()
# Out:
#                  AAPL    AMZN      GOOGL       MSFT   TSLA  TWTR
# Date
# 2012-01-03  14.686786  8.9515  16.651901  26.770000  5.616   NaN
# 2012-01-04  14.765714  8.8755  16.723724  27.400000  5.542   NaN
# 2012-01-05  14.929643  8.8805  16.491741  27.680000  5.424   NaN
# 2012-01-06  15.085714  9.1305  16.266768  28.110001  5.382   NaN
# 2012-01-09  15.061786  8.9280  15.577077  27.740000  5.450   NaN

# %%
close.pct_change().dropna()
# Out:
#                 AAPL      AMZN     GOOGL      MSFT      TSLA      TWTR
# Date
# 2013-11-08  0.015747  0.019647  0.008016  0.007467 -0.013021 -0.072383
# 2013-11-11 -0.002901  0.011618 -0.005354 -0.005029  0.048931  0.030012
# 2013-11-12  0.001850 -0.013686  0.001178 -0.006119 -0.047685 -0.023310
# 2013-11-13  0.001192  0.019140  0.020449  0.021413  0.006531  0.016706
# 2013-11-14  0.014463  0.031385  0.002673 -0.003669 -0.007931  0.049061
# ...              ...       ...       ...       ...       ...       ...
# 2022-08-08 -0.002903 -0.009872 -0.001447 -0.009155  0.007819  0.009878
# 2022-08-09  0.000303 -0.011333 -0.005712  0.007063 -0.024413 -0.002562
# 2022-08-10  0.026195  0.035261  0.026323  0.024300  0.038906  0.037357
# 2022-08-11 -0.004432 -0.014367 -0.007185 -0.007401 -0.026249 -0.011029
# 2022-08-12  0.021426  0.020691  0.023898  0.017037  0.046750  0.007283
#
# [2205 rows x 6 columns]

# %%
ret = close.pct_change().dropna()

# %%
ret.head()
# Out:
#                 AAPL      AMZN     GOOGL      MSFT      TSLA      TWTR
# Date
# 2013-11-08  0.015747  0.019647  0.008016  0.007467 -0.013021 -0.072383
# 2013-11-11 -0.002901  0.011618 -0.005354 -0.005029  0.048931  0.030012
# 2013-11-12  0.001850 -0.013686  0.001178 -0.006119 -0.047685 -0.023310
# 2013-11-13  0.001192  0.019140  0.020449  0.021413  0.006531  0.016706
# 2013-11-14  0.014463  0.031385  0.002673 -0.003669 -0.007931  0.049061

# %%
ret.describe().T.loc[:,['mean','std']]
# Out:
#            mean       std
# AAPL   0.001179  0.017998
# AMZN   0.001170  0.020367
# GOOGL  0.000856  0.016887
# MSFT   0.001072  0.016807
# TSLA   0.002189  0.035113
# TWTR   0.000575  0.033888

# %%
summary = ret.describe().T.loc[:,['mean','std']]
summary
# Out:
#            mean       std
# AAPL   0.001179  0.017998
# AMZN   0.001170  0.020367
# GOOGL  0.000856  0.016887
# MSFT   0.001072  0.016807
# TSLA   0.002189  0.035113
# TWTR   0.000575  0.033888

# %%
summary['mean'] =summary['mean'].mul(252)
summary['std'] = summary['std'].mul(np.sqrt(252))

# %%
summary
# Out:
#            mean       std
# AAPL   0.297085  0.285709
# AMZN   0.294877  0.323316
# GOOGL  0.215693  0.268077
# MSFT   0.270196  0.266800
# TSLA   0.551697  0.557405
# TWTR   0.144858  0.537950

# %%
summary.plot(kind='scatter', x= 'std', y='mean', figsize=(15,10), s= 200,fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, 'std']+0.004, summary.loc[i,'mean']+0.003), size=15)
plt.xlabel('ann. Risk(std)', fontsize=15)
plt.ylabel('ann. Return', fontsize=15)
plt.title('RISK | RETURN', fontsize=20);

# %% [markdown]
# # Financial Time Series - Covariance and Correlation

# %%
ret.head()
# Out:
#                 AAPL      AMZN     GOOGL      MSFT      TSLA      TWTR
# Date
# 2013-11-08  0.015747  0.019647  0.008016  0.007467 -0.013021 -0.072383
# 2013-11-11 -0.002901  0.011618 -0.005354 -0.005029  0.048931  0.030012
# 2013-11-12  0.001850 -0.013686  0.001178 -0.006119 -0.047685 -0.023310
# 2013-11-13  0.001192  0.019140  0.020449  0.021413  0.006531  0.016706
# 2013-11-14  0.014463  0.031385  0.002673 -0.003669 -0.007931  0.049061

# %%
ret.cov()
# Out:
#            AAPL      AMZN     GOOGL      MSFT      TSLA      TWTR
# AAPL   0.000324  0.000198  0.000181  0.000201  0.000258  0.000198
# AMZN   0.000198  0.000415  0.000218  0.000209  0.000277  0.000222
# GOOGL  0.000181  0.000218  0.000285  0.000204  0.000228  0.000201
# MSFT   0.000201  0.000209  0.000204  0.000282  0.000241  0.000194
# TSLA   0.000258  0.000277  0.000228  0.000241  0.001233  0.000324
# TWTR   0.000198  0.000222  0.000201  0.000194  0.000324  0.001148

# %%
ret.corr()
# Out:
#            AAPL      AMZN     GOOGL      MSFT      TSLA      TWTR
# AAPL   1.000000  0.539746  0.596844  0.664568  0.407967  0.325142
# AMZN   0.539746  1.000000  0.634621  0.611482  0.387191  0.321837
# GOOGL  0.596844  0.634621  1.000000  0.717320  0.384349  0.350910
# MSFT   0.664568  0.611482  0.717320  1.000000  0.408822  0.341355
# TSLA   0.407967  0.387191  0.384349  0.408822  1.000000  0.272284
# TWTR   0.325142  0.321837  0.350910  0.341355  0.272284  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.heatmap(ret.corr(), cmap='Reds', annot=True, annot_kws={'size':15});
